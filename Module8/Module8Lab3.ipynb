# %% [markdown]
# <a href="https://colab.research.google.com/github/himavanth07/MachineLearning/blob/main/Module8Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-13 09:09:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   213MB/s    in 0.3s
#
# 2022-06-13 09:09:17 (213 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18143  cs/0407040v1  In this paper we present and evaluate a search...    cs
# 8814    1408.3934v1  The use of short text messages in social media...    cs
# 17428  1711.01505v1  This paper presents a summary of the first Wor...    cs
# 7794   1803.04186v1  We consider a neural network architecture with...  stat
# 3220    1403.5370v1  The aim of this paper is to present a new meth...  stat
# ...             ...                                                ...   ...
# 22104   1411.5271v2  Diffusion-weighted MR imaging (DWI) is the onl...  stat
# 31485  1803.05258v1  In this paper, we introduce the Face Magnifier...    cs
# 34436  1608.02519v1  The tremendous growth of social media content ...    cs
# 21622   1203.4354v1  Regularized kernel methods such as, e.g., supp...  stat
# 2557   1605.00596v1  We investigate an efficient context-dependent ...  stat
#
#                                                    title  year  \
# 18143  Decomposition Based Search - A theoretical and...  2004
# 8814   On Detecting Messaging Abuse in Short Text Mes...  2014
# 17428  Towards Linguistically Generalizable NLP Syste...  2017
# 7794   R3Net: Random Weights, Rectifier Linear Units ...  2018
# 3220   Using n-grams models for visual semantic place...  2014
# ...                                                  ...   ...
# 22104  Quantifying error in estimates of human brain ...  2014
# 31485  Face-MagNet: Magnifying Feature Maps to Detect...  2018
# 34436  Topic Modelling and Event Identification from ...  2016
# 21622  Asymptotic Confidence Sets for General Nonpara...  2012
# 2557         Graph Clustering Bandits for Recommendation  2016
#
#                                                 keywords
# 18143  [decomposition, subproblem, generation, subpro...
# 8814   [messaging, communication, popularity, increme...
# 17428  [linguistically, generalizable, processing, as...
# 7794   [architecture, randomized, rectified, architec...
# 3220   [recognition, characterization, efficient, fil...
# ...                                                  ...
# 22104  [diffusion, currently, connections, different,...
# 31485  [introduce, magnifier, framework, discriminati...
# 34436  [tremendous, development, analytics, understan...
# 21622  [regularized, regression, constitute, importan...
# 2557   [investigate, efficient, dependent, clustering...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18143    [decomposition, subproblem, generation, subpro...
# 8814     [messaging, communication, popularity, increme...
# 17428    [linguistically, generalizable, processing, as...
# 7794     [architecture, randomized, rectified, architec...
# 3220     [recognition, characterization, efficient, fil...
#                                ...
# 21883    [factorial, similarities, truncated, advantage...
# 29365    [automatic, unsupervised, detection, classific...
# 25406    [correlation, information, representation, dis...
# 7641     [generative, adversarial, framework, convoluti...
# 21644    [geometrically, motivated, algorithm, nonnegat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6d6a4d89-40cc-4a93-9359-6d184c86f7f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d6a4d89-40cc-4a93-9359-6d184c86f7f6")) {                    Plotly.newPlot(                        "6d6a4d89-40cc-4a93-9359-6d184c86f7f6",                        [{"x":["splitting","experimental","satisfaction","optimization","effective","discrepancy","assumptions","according","theoretical","heuristic","promising","computationally","successful","strategies","realistic","iterative","subproblem","subproblems","generation","experiments","comparable","constraint","evaluation","theoretically","probability","decomposition","subdomains","enhancing","different","additional","traditional","messaging","clustering","linguistic","challenges","popularity","behavioral","communication","detecting","detection","processing","filtering","effectiveness","solutions","increment","techniques","contractions","normalization","approaches","telecommunications","performance","researchers","discussion","associated","distributions","participation","motivation","linguistics","generalizability","linguistically","generalizable","highlighted","lipschitz","arbitrarily","robustness","artificial","randomized","continuity","architecture","discrimination","contracting","rectifier","rectified","perturbation","recognition","highlights","evaluated","efficient","integrate","precisely","classical","algorithm","influence","parameters","characterization","improvements","applications","benchmarks","continuous","extensive","consistently","advantages","constraints","discovery","classification","challenging","demonstrate","important","framework","efficiently","stochastic","application","imputation","prediction","partitions","collection","nonparametric","technique","forecasting","foundation","temporally","discovers","interpretable","distribution","stationary","appropriate","predictive","inferences","macroeconomic","posterior","demonstrating","restaurant","extension","baselines","independent","multivariate","prevention","competitive","computational","situation","meaningful","interaction","cognitive","description","specifically","descriptions","engineered","cleansing","deployment","potential","extraction","categories","dependent","developed","development","knowledge","moderately","achieving","aggregate","feasibility","monitoring","outperforming","parameter","available","disaggregation","represent","acquisition","frequency","extensible","scenarios","understood","evaluates","difficulty","entangled","applicable","necessary","sufficient","absolutely","component","established","quantitative","landscapes","generality","qualitative","algorithms","retrieval","hierarchical","assigning","furthermore","significant","statistical","capabilities","incorporates","information","difficult","emotional","interests","simultaneously","contribution","inference","determine","structure","inappropriate","incorporating","conditional","gradients","prominent","increasing","transferable","identification"],"y":[13,395,25,318,254,14,62,107,152,64,116,83,73,111,52,70,3,7,130,594,100,84,246,44,186,61,1,16,747,124,179,3,157,83,114,15,6,63,85,370,282,61,199,156,2,407,1,30,422,2,895,85,32,119,113,8,20,14,4,11,6,8,8,13,97,122,19,6,258,19,2,1,6,13,358,7,145,408,42,22,108,828,49,241,28,109,404,95,101,180,35,87,136,63,482,284,550,342,532,161,130,258,4,234,14,57,17,252,20,16,14,8,33,220,32,63,48,11,0,30,24,5,72,54,145,13,1,134,304,30,47,75,48,71,157,35,15,1,23,158,130,78,63,182,112,339,4,95,20,23,36,28,123,299,2,124,29,48,5,90,26,12,48,4,52,89,68,2,108,53,60,7,17,50,611,98,103,19,153,255,170,40,30,707,156,12,14,118,63,217,66,349,4,49,107,32,14,103,6,101],"type":"bar"},{"x":["splitting","experimental","satisfaction","optimization","effective" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.8666666666666667);'>coordination</span> <span style=''>of</span> <span style=''>working</span> <span style=''>memory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3586956521739132);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>non</span> <span style=''>human</span> <span style=''>primates</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>a</span> <span style=''>trial</span> <span style=''>and</span> <span style=''>error</span> <span style=''>problem</span> <span style=''>solving</span> <span style=''>task</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Accumulating</span> <span style=''>evidence</span> <span style=''>suggest</span> <span style=''>that</span> <span style=''>human</span> <span style=''>behavior</span> <span style=''>in</span> <span style=''>trial</span> <span style=''>and</span> <span style=''>error</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>decisions</span> <span style=''>between</span> <span style=''>discrete</span> <span style=''>actions</span> <span style=''>may</span> <span style=''>involve</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.37999999999999995);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3586956521739132);'>reinforcement</span> <span style=''>learning</span> <span style=''>(RL)</span> <span style=''>and</span> <span style=''>working</span> <span style=''>memory</span> <span style=''>(WM)</span> <span style=''>While</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>activity</span> <span style=''>at</span> <span style=''>stake</span> <span style=''>in</span> <span style=''>this</span> <span style=''>type</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>often</span> <span style=''>involve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style=''>non</span> <span style=''>human</span> <span style=''>primate</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>neurophysiological</span> <span style=''>results</span> <span style=''>it</span> <span style=''>is</span> <span style=''>not</span> <span style=''>clear</span> <span style=''>whether</span> <span style=''>monkeys</span> <span style=''>use</span> <span style=''>similar</span> <span style=''>combined</span> <span style=''>RL</span> <span style=''>and</span> <span style=''>WM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>these</span> <span style=''>tasks</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>analyzed</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>five</span> <span style=''>monkeys</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.349112426035503);'>combining</span> <span style=''>RL</span> <span style=''>and</span> <span style=''>WM</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>based</span> <span style=''>analysis</span> <span style=''>approach</span> <span style=''>enables</span> <span style=''>to</span> <span style=''>not</span> <span style=''>only</span> <span style=''>fit</span> <span style=''>trial</span> <span style=''>by</span> <span style=''>trial</span> <span style=''>choices</span> <span style=''>but</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>With</span> <span style=''>Uniform</span> <span style=''>Feature</span> <span style=''>Noise</span> <br/><br/><span style=''>In</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>chooses</span> <span style=''>values</span> <span style=''>for</span> <span style=''>feature</span> <span style=''>X</span> <span style=''>and</span> <span style=''>an</span> <span style=''>oracle</span> <span style=''>returns</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>label</span> <span style=''>Y</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>noise</span> <span style=''>in</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>could</span> <span style=''>arise</span> <span style=''>either</span> <span style=''>because</span> <span style=''>X</span> <span style=''>itself</span> <span style=''>is</span> <span style=''>being</span> <span style=''>measured</span> <span style=''>or</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transmission</span> <span style=''>to</span> <span style=''>the</span> <span style=''>oracle</span> <span style=''>or</span> <span style=''>the</span> <span style=''>oracle</span> <span style=''>returns</span> <span style=''>the</span> <span style=''>label</span> <span style=''>of</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>query</span> <span style=''>point</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>feature</span> <span style=''>noise</span> <span style=''>is</span> <span style=''>known</span> <span style=''>as</span> <span style=''>errors</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>in</span> <span style=''>non</span> <span style=''>active</span> <span style=''>settings</span> <span style=''>However</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>noise</span> <span style=''>in</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>before</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Berkson</span> <span style=''>errors</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>model</span> <span style=''>with</span> <span style=''>additive</span> <span style=''>uniform</span> <span style=''>noise</span> <span style=''>of</span> <span style=''>width</span> <span style=''>sigma</span> <span style=''>Our</span> <span style=''>simple</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>revealing</span> <span style=''>setting</span> <span style=''>is</span> <span style=''>that</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Entropic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Causality</span> <span style=''>and</span> <span style=''>Greedy</span> <span style=''>Minimum</span> <span style=''>Entropy</span> <span style=''>Coupling</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>two</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.4422110552763819);'>variables</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.5599999999999999);'>observational</span> <span style=''>data</span> <span style=''>We</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>called</span> <span style=''>entropic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>that</span> <span style=''>works</span> <span style=''>in</span> <span style=''>a</span> <span style=''>very</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.4234234234234234);'>functional</span> <span style=''>model</span> <span style=''>but</span> <span style=''>makes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30612244897959184);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>unobserved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exogenous</span> <span style=''>variable</span> <span style=''>has</span> <span style=''>small</span> <span style=''>entropy</span> <span style=''>in</span> <span style=''>the</span> <span style=''>true</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>requires</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>entropy</span> <span style=''>coupling</span> <span style=''>problem</span> <span style=''>Given</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.32738095238095244);'>distributions</span> <span style=''>of</span> <span style=''>m</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.4422110552763819);'>variables</span> <span style=''>each</span> <span style=''>on</span> <span style=''>n</span> <span style=''>states</span> <span style=''>find</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>with</span> <span style=''>minimum</span> <span style=''>entropy</span> <span style=''>that</span> <span style=''>respects</span> <span style=''>the</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginals</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>a</span> <span style=''>concave</span> <span style=''>function</span> <span style=''>of</span> <span style=''>nm</span> <span style='background-color:rgba(255, 0, 0, 0.4422110552763819);'>variables</span> <span style=''>over</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>polytope</span> <span style=''>defined</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovering</span> <span style=''>patterns</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structurally</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>(BSI)</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>unifilar</span> <span style=''>HMM</span> <span style=''>(uHMM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>topologies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>a</span> <span style=''>data</span> <span style=''>series</span> <span style=''>We</span> <span style=''>employ</span> <span style=''>a</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enumeration</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>topological</span> <span style=''>epsilon</span> <span style=''>machines</span> <span style=''>(A</span> <span style=''>sequel</span> <span style=''>then</span> <span style=''>removes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>topological</span> <span style=''>restriction)</span> <span style=''>This</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>uHMM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>topologies</span> <span style=''>has</span> <span style=''>the</span> <span style=''>added</span> <span style=''>benefit</span> <span style=''>that</span> <span style=''>inferred</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>epsilon</span> <span style=''>machines</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irrespective</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Properties</span> <span style=''>of</span> <span style=''>epsilon</span> <span style=''>machines</span> <span style=''>and</span> <span style=''>uHMMs</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivation</span> <span style=''>of</span> <span style=''>analytic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12218649517684887)
# 	processing (0.1007502679528403)
# 	experimental (0.1411218292247231)
# 	segmentation (0.07216863165416221)
# 	architecture (0.09217577706323687)
# 	information (0.2525902107895677)
# 	detection (0.1321900678813862)
# 	recognition (0.1279028224365845)
# 	different (0.26688102893890675)
# 	convolutional (0.13504823151125403)
#
# Some Statistics words are:
# 	stochastic (0.13343328335832083)
# 	theoretical (0.14742628685657172)
# 	algorithm (0.39480259870064965)
# 	statistical (0.15992003998001)
# 	distribution (0.1794102948525737)
# 	variables (0.14342828585707146)
# 	estimation (0.18240879560219891)
# 	dimensional (0.18840579710144928)
# 	inference (0.20839580209895053)
# 	regression (0.18040979510244878)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fb4e4d04-f3a6-4561-8d2e-db84d6b9e38d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb4e4d04-f3a6-4561-8d2e-db84d6b9e38d")) {                    Plotly.newPlot(                        "fb4e4d04-f3a6-4561-8d2e-db84d6b9e38d",                        [{"x":["splitting","experimental","satisfaction","optimization","effective","discrepancy","assumptions","according","theoretical","heuristic","promising","computationally","successful","strategies","realistic","iterative","subproblem","subproblems","generation","experiments","comparable","constraint","evaluation","theoretically","probability","decomposition","subdomains","enhancing","different","additional","traditional","messaging","clustering","linguistic","challenges","popularity","behavioral","communication","detecting","detection","processing","filtering","effectiveness","solutions","increment","techniques","contractions","normalization","approaches","telecommunications","performance","researchers","discussion","associated","distributions","participation","motivation","linguistics","generalizability","linguistically","generalizable","highlighted","lipschitz","arbitrarily","robustness","artificial","randomized","continuity","architecture","discrimination","contracting","rectifier","rectified","perturbation","recognition","highlights","evaluated","efficient","integrate","precisely","classical","algorithm","influence","parameters","characterization","improvements","applications","benchmarks","continuous","extensive","consistently","advantages","constraints","discovery","classification","challenging","demonstrate","important","framework","efficiently","stochastic","application","imputation","prediction","partitions","collection","nonparametric","technique","forecasting","foundation","temporally","discovers","interpretable","distribution","stationary","appropriate","predictive","inferences","macroeconomic","posterior","demonstrating","restaurant","extension","baselines","independent","multivariate","prevention","competitive","computational","situation","meaningful","interaction","cognitive","description","specifically","descriptions","engineered","cleansing","deployment","potential","extraction","categories","dependent","developed","development","knowledge","moderately","achieving","aggregate","feasibility","monitoring","outperforming","parameter","available","disaggregation","represent","acquisition","frequency","extensible","scenarios","understood","evaluates","difficulty","entangled","applicable","necessary","sufficient","absolutely","component","established","quantitative","landscapes","generality","qualitative","algorithms","retrieval","hierarchical","assigning","furthermore","significant","statistical","capabilities","incorporates","information","difficult","emotional","interests","simultaneously","contribution","inference","determine","structure","inappropriate","incorporating","conditional","gradients","prominent","increasing","transferable","identification","dimension","including","reduction","significantly","substitute","especially","transferability","generating","technologies","leveraging","misclassification","accomplished","adversarial","vulnerability","attacking","importance","noticeable","exploiting","autonomous","coordinate","outperforms","indicated","conventionally","activated","drastically","demanding","footprint","computation","frequently","recovering","applicability","inversion","activation","segmentation","succession","providing","optimized","obtaining","intermediate","straightforward","frameworks","cityscapes","unsatisfactory","regressions","functional","retrieving","selection","practical","maximization","likelihood","numerical","inappropriately","performed","partition", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	macroeconomic
# 	regressions
# 	inappropriately
# 	stochasticity
# 	eigenspace
# 	triggering
# 	amortized
# 	unnormalized
# 	ultrahigh
# 	amplitude
# 	parametrisation
# 	pharmaceutical
# 	resistance
# 	proteomics
# 	incorrectly
# 	gaussianization
# 	stitching
# 	ergodicity
# 	encountering
# 	martingale
# Some words which never appear in Statistics papers:
# 	messaging
# 	telecommunications
# 	participation
# 	linguistically
# 	entangled
# 	conventionally
# 	activated
# 	succession
# 	cityscapes
# 	propositional
# 	intensional
# 	competitions
# 	discourse
# 	cooperation
# 	pervasive
# 	cooperate
# 	butterfly
# 	assistance
# 	automotive
# 	examinations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0741799624950045e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
